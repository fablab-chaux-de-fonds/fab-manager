# %%
import pandas as pd
import base64
import os
import json

path=r'../../app/assets/images/crowdmachine/400x400'
def to_base64(file):
    with open(file, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('ascii')

url = 'https://docs.google.com/spreadsheets/d/1uS8elJvel5WN_dvNN7ziWpwc-Qz3lVh0GdPCYTN90-s/gviz/tq?tqx=out:csv&sheet='
df = pd.read_csv(url)[['sort', 'id', 'title', 'description', 'specification']]

df['image'] = df.apply(lambda row: to_base64(os.path.join(path, str(row.id) + '_400x400.png')), axis=1)
  
# df.to_json('crowdmachine.json', orient='records')
data = {'data': df.to_dict(orient='records')}
with open('crowdmachine.json', 'w', encoding='utf-8') as fp:
    json.dump(data, fp)
# Out:
# ../../app/assets/images/crowdmachine/400x400/1_400x400.png
# ../../app/assets/images/crowdmachine/400x400/2_400x400.png
# ../../app/assets/images/crowdmachine/400x400/3_400x400.png
# ../../app/assets/images/crowdmachine/400x400/4_400x400.png
# ../../app/assets/images/crowdmachine/400x400/5_400x400.png
# ../../app/assets/images/crowdmachine/400x400/6_400x400.png
# ../../app/assets/images/crowdmachine/400x400/7_400x400.png
# ../../app/assets/images/crowdmachine/400x400/8_400x400.png
# ../../app/assets/images/crowdmachine/400x400/9_400x400.png
# ../../app/assets/images/crowdmachine/400x400/10_400x400.png
# ../../app/assets/images/crowdmachine/400x400/11_400x400.png
# ../../app/assets/images/crowdmachine/400x400/12_400x400.png
# ../../app/assets/images/crowdmachine/400x400/13_400x400.png
# ../../app/assets/images/crowdmachine/400x400/14_400x400.png
# ../../app/assets/images/crowdmachine/400x400/15_400x400.png
# ../../app/assets/images/crowdmachine/400x400/16_400x400.png
# ../../app/assets/images/crowdmachine/400x400/17_400x400.png
# ../../app/assets/images/crowdmachine/400x400/18_400x400.png
# ../../app/assets/images/crowdmachine/400x400/19_400x400.png
# ../../app/assets/images/crowdmachine/400x400/20_400x400.png
# ../../app/assets/images/crowdmachine/400x400/21_400x400.png
# ../../app/assets/images/crowdmachine/400x400/22_400x400.png

# %%
data
# Out:
# {'data': [{'sort': 1,
#    'id': 1,
#    'title': 'Pied à coulisse',
#    'description': 'Nous vous proposerons un atelier de mécanique avec tour fraiseuse etc... mais cela sera bien de pouvoir mesurer les pièces qui y seront fabriquées! Nous recherchons un pied à coulisse universel pour le mesurage intérieur, extérieur et de profondeur.',
#    'specification': 'Écran LCD\nMode de mesure ABS\nMode économique automatique\nArrêt automatique\nConversion mm/pouce\n',
#    'image': '...'},
#   {'sort': 2,
#    'id': 2,
#    'title': 'Beamer',
#    'description': 'Afin d’être en mesure de projeter des vidéos et des informations lors de nos futurs workshops, nous recherchons un beamer de résolution et de taille raisonnable.',
#    'specification': "Format image 16:9\nLumen image (ANSI)2500 lm\nDésignation résolution de projection Full HD Résolution projection1920 x 1080 px\nTechnologie projection LCD\nRapport contraste 60'000:1\nDistance projection min.2.35 m\nRapport projection min.1.33:1 \nRapport projection max.2.16:1\nEcran visible76 et 762 cm\nLuminosité f/1.51 et 1.99 \nFacteur zoom optique1.6 x\nAméloration image\nCorrection Keystone, numérique: -30/+30 vertical\nCorrection Keystone, numérique: -30/+30 horizontal\nDiffusion 3D Oui",
#    'image': '...'},
#   {'sort': 3,
#    'id': 3,
#    'title': 'Outils à main bois',
#    'description': 'Pour notre atelier bois nous recherchons un set complet d’outils bois à main comprenant des rabots, limes, ciseaux à bois, scies, outils de traçage, etc...',
#    'specification': 'Outils de bonne qualité',
#    'image': '...'},
#   {'sort': 4,
#    'id': 4,
#    'title': 'Haut-parleurs / système audio',
#    'description': 'Dans le but de rendre le fablab encore plus agréable à fréquenter nous avons besoin de plusieurs haut parleurs avec ampli ou autre système de sono type home cinema.',
#    'specification': "Puissance nominale (RMS)\n100 W\nFréquence\n50Hz - 20'000 Hz\nImpédance\n10 Ohm\nAlimentation électrique\nBloc d’alimentation",
#    'image': '...'},
#   {'sort': 5,
#    'id': 5,
#    'title': 'Imprimante 2D/scanner',
#    'description': "Pour l'instant nous nous sommes surtout concentrés sur les imprimantes 3D... Mais imprimer et scanner du papier peut aussi s'avérer utile!",
#    'specification': 'de préférence laser / format A4 A5 pourquoi pas A3',
#    'image': '...'},
#   {'sort': 6,
#    'id': 6,
#    'title': 'Machine à café ',
#    'description': "Afin d'entretenir l'état d'éveil des visiteurs du Fablab, nous recherchons une machine à café domestique",
#    'specification': 'plutôt des dosettes que des capsules',
#    'image': '...'},
#   {'sort': 7,
#    'id': 7,
#    'title': 'Poste à souder (2x)',
#    'description': 'Pour tout ce qui est soudure des composants éléctronique nous aurons besoin de plusieurs postes à souder',
#    'specification': "le réglage de la température n'est pas indispensable mais souhaité",
#    'image': '...'},
#   {'sort': 8,
#    'id': 8,
#    'title': 'Aspirateur (ménage)',
#    'description': "Afin d'entretenir les sols des espaces communautaires du Fablab, nous recherchons un aspiratuer domestique",
#    'specification': "D'une puissance suffisante et idéalement sans sac",
#    'image': '...'},
#   {'sort': 9,
#    'id': 9,
#    'title': 'Caisse à outil complète (à séparer?)',
#    'description': "Nous avons besoin d'une caisse à outil complète qui constituera la base de nos outils à main",
#    'specification': 'marteau, différentes pinces, assortiment de tournevis, clé à molette, jeu de clés imbus, etc...',
#    'image': '...'},
#   {'sort': 10,
#    'id': 10,
#    'title': 'Scie à onglet',
#    'description': 'Afin de pouvoir scier des blocs de bois selon un agle précis nous recherchons une scie à onglet',
#    'specification': '1400 W, diamètre de la lame env. : 216 mm, 5500 tr/min',
#    'image': '...'},
#   {'sort': 11,
#    'id': 11,
#    'title': 'Perçeuse/visseuse à main',
#    'description': 'Outil indispensable dans tout fablab pour construire, démonter ou encore réparer, nous recherchons une perceuse visseuse.',
#    'specification': "L'autonomie et la puissance sont les critères les plus iportants pour nous",
#    'image': '...'},
#   {'sort': 12,
#    'id': 12,
#    'title': 'Sableuse',
#    'description': 'Cela pourraît être sympa de sabler des pièces réalisée sur notre tour ou sur la fraiseuse',
#    'specification': 'Pas de critères particuliers',
#    'image': '...'},
#   {'sort': 13,
#    'id': 13,
#    'title': 'Fraiseuse 3 axes numérique (petite)',
#    'description': 'Nous vous en proposerons une énorme mais purquoi pas une 2ème à taille humaine pour réaliser des projets plus raisonnables',
#    'specification': "Pas de critères particuliers si ce n'est les dimensions, elle doit tenir sur un établi",
#    'image': '...'},
#   {'sort': 14,
#    'id': 14,
#    'title': 'Outils à main mécanique',
#    'description': 'Nous avons les machines mais nous aurons besoins dôutils tels que des tarauds à main, des limes etc....',
#    'specification': 'les outils doivent être de bonne qualité',
#    'image': '...'},
#   {'sort': 15,
#    'id': 15,
#    'title': 'Aspirateur industriel eau + poussière',
#    'description': 'Afin de nettoyer les surfaces ne nos ateliers nous recherchons un aspirateur de type industriel pouvant aspirer aussi bien les copeaux et la poussières que les liquides',
#    'specification': "Une puissance d'aspiration élevée serait appréciable",
#    'image': '...'},
#   {'sort': 16,
#    'id': 16,
#    'title': 'Scie circulaire à main',
#    'description': "Nous disposons d'une scie circulaire fixe mais il pourra être pratique d'en avoir une plus mobile",
#    'specification': 'une puissance de 1400W serait appréciable',
#    'image': '...'},
#   {'sort': 17,
#    'id': 17,
#    'title': 'Aspirateur à copeaux',
#    'description': 'Afin de le monter sur les machines produisant le plus de poussière nous recherchons un aspirateur à copeaux',
#    'specification': "l'aspirateur doit être compatible avec des sacs de grands volumes",
#    'image': '...'},
#   {'sort': 18,
#    'id': 18,
#    'title': 'Disqueuse',
#    'description': "Afin de pouvoir tronconner des plaques d'acier et autres nous recherchons une meuleuse d'angle",
#    'specification': '2000-2500W',
#    'image': '...'},
#   {'sort': 19,
#    'id': 19,
#    'title': 'Imprimante 3D ',
#    'description': 'Nous en avons déjà quelques une mais une de plus ne sera jamais de trop',
#    'specification': 'A dépôt de fil ou poudre\n',
#    'image': '...'},
#   {'sort': 20,
#    'id': 20,
#    'title': "Masque pour soudure à l'arc",
#    'description': 'Nous avons le matériel de soudure mais il nous manque le masque de protection',
#    'specification': 'Pas de critères particuliers',
#    'image': '...'},
#   {'sort': 21,
#    'id': 21,
#    'title': 'chaises',
#    'description': 'Nous rechercons des chaises emplilables compatibles avec celles que nous avons déjà',
#    'specification': "L'idéal serait qu'il s'agisse exactement des même que nous possédons  ou alors un lot d'une 10 aine de pièces",
#    'image': '...'},
#   {'sort': 22,
#    'id': 22,
#    'title': 'Découpeuse vynil (grande)',
#    'description': 'que ce soit pour personaliser des habits ou décorer une vitrine une décpupese vinyl est toujours pratique',
#    'specification': 'larguer supérieur à 800mm',
#    'image': '...'}]}
